# %%
from submit_training_job import cluster_login, create_cluster, \
    submit_job, wait_for_completion, clean_up

# %%
server_url = 'https://api.cluster-vpgz2.dynamic.opentlc.com:6443'
token = 'sha256~yyrm-HscKJP2RtA8GHeF4yC4Pby7mx3vXW1Eu1QU9do'

# %%
auth = cluster_login(server_url, token)
# Out:
# logging into cluster at https://api.cluster-vpgz2.dynamic.opentlc.com:6443
# Insecure request warnings have been disabled
# login successful

# %%
cluster = create_cluster()
# Out:
# creating framework cluster
# Written to: mnist-test.yaml
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ No resources found, have you run cluster.up() yet?                                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# booting cluster
# Waiting for requested resources to be set up...
# Requested cluster is up and running!
# Dashboard is ready!
# cluster is online
# cluster details:
#                    🚀 CodeFlare Cluster Details 🚀
#
#  ╭─────────────────────────────────────────────────────────────────╮
#  │   Name                                                          │
#  │   mnist-test                                        Active ✅   │
#  │                                                                 │
#  │   URI: ray://mnist-test-head-svc.default.svc:10001              │
#  │                                                                 │
#  │   ]8;id=628834;http://ray-dashboard-mnist-test-default.apps.cluster-vpgz2.dynamic.opentlc.com\Dashboard🔗]8;;\                                                   │
#  │                                                                 │
#  │                       Cluster Resources                         │
#  │   ╭── Workers ──╮  ╭───────── Worker specs(each) ─────────╮     │
#  │   │  # Workers  │  │  Memory      CPU         GPU         │     │
#  │   │             │  │                                      │     │
#  │   │  2          │  │  8~8         2           0           │     │
#  │   │             │  │                                      │     │
#  │   ╰─────────────╯  ╰──────────────────────────────────────╯     │
#  ╰─────────────────────────────────────────────────────────────────╯

# %%
job = submit_job(cluster)
# Out:
# The Ray scheduler does not support port mapping.
# 2023-11-03 01:46:42,392	INFO dashboard_sdk.py:338 -- Uploading package gcs://_ray_pkg_bb1e6d3bc4630ea8.zip.
# 2023-11-03 01:46:42,393	INFO packaging.py:518 -- Creating a file package for local directory '/tmp/torchx_workspacex0dvli5o'.
# creating and submitting job
# job submitted

# %%
wait_for_completion(job)
# Out:
# awaiting job completion
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: False
# job is finished: True
# job finished with status: AppStatus:
#   msg: !!python/object/apply:ray.dashboard.modules.job.common.JobStatus
#   - SUCCEEDED
#   num_restarts: -1
#   roles:
#   - replicas:
#     - hostname: <NONE>
#       id: 0
#       role: ray
#       state: !!python/object/apply:torchx.specs.api.AppState
#       - 4
#       structured_error_msg: <NONE>
#     role: ray
#   state: SUCCEEDED (4)
#   structured_error_msg: <NONE>
#   ui_url: null
#
# job logs:
#
# ('[RayActor(name=\'mnist\', command=[\'bash\', \'-c\', "torchrun '
#  '--rdzv_backend static --rdzv_endpoint ${TORCHX_RANK0_HOST:=localhost}:29500 '
#  "--rdzv_id 'mnisttest-g96zpfmmm0273' --nnodes 2 --nproc_per_node 1 --tee 3 "
#  '--role \'\' --node_rank \'0\' mnist.py"], env={\'AWS_S3_ENDPOINT\': '
#  "'http://minio-service.minio.svc:9000', 'AWS_ACCESS_KEY_ID': 'minio', "
#  "'AWS_SECRET_ACCESS_KEY': 'minio123', 'AWS_S3_BUCKET': 'mybucket', "
#  "'hidden_size': '16', 'max_epochs': '1', 'TORCHX_TRACKING_EXPERIMENT_NAME': "
#  "'default-experiment', 'LOGLEVEL': 'WARNING', 'TORCHX_JOB_ID': "
#  "'ray://torchx/mnisttest-g96zpfmmm0273'}, num_cpus=2, num_gpus=0, "
#  "min_replicas=2), RayActor(name='mnist', command=['bash', '-c', "
#  '"torchrun --rdzv_backend static --rdzv_endpoint '
#  "${TORCHX_RANK0_HOST:=localhost}:29500 --rdzv_id 'mnisttest-g96zpfmmm0273' "
#  "--nnodes 2 --nproc_per_node 1 --tee 3 --role '' --node_rank '1' "
#  'mnist.py"], env={\'AWS_S3_ENDPOINT\': '
#  "'http://minio-service.minio.svc:9000', 'AWS_ACCESS_KEY_ID': 'minio', "
#  "'AWS_SECRET_ACCESS_KEY': 'minio123', 'AWS_S3_BUCKET': 'mybucket', "
#  "'hidden_size': '16', 'max_epochs': '1', 'TORCHX_TRACKING_EXPERIMENT_NAME': "
#  "'default-experiment', 'LOGLEVEL': 'WARNING', 'TORCHX_JOB_ID': "
#  "'ray://torchx/mnisttest-g96zpfmmm0273'}, num_cpus=2, num_gpus=0, "
#  'min_replicas=2)]\n'
#  '2023-11-02 18:47:38,802\tINFO worker.py:1329 -- Using address '
#  '10.134.0.130:6379 set in the environment variable RAY_ADDRESS\n'
#  '2023-11-02 18:47:38,802\tINFO worker.py:1458 -- Connecting to existing Ray '
#  'cluster at address: 10.134.0.130:6379...\n'
#  '2023-11-02 18:47:38,811\tINFO worker.py:1633 -- Connected to Ray cluster. '
#  'View the dashboard at \x1b\x1b10.134.0.130:8265 \x1b\x1b\n'
#  'Waiting for minimum placement group to start.\n'
#  'Successfully created placement groups\n'
#  'rdzv_endpoint set to 10.134.0.130 for actor '
#  '2cd4ebce5bde2b44108b061402000000\n'
#  'rdzv_endpoint set to 10.134.0.130 for actor '
#  '0828dc4edad993652dc48edd02000000\n'
#  'Successfully placed command actors\n'
#  'Entering main loop, start executing the script on worker nodes\n'
#  'running ray.wait on '
#  '[ObjectRef(e082c90ab8422b002cd4ebce5bde2b44108b06140200000001000000), '
#  'ObjectRef(ce868e48e2fa9a940828dc4edad993652dc48edd0200000001000000)]\n'
#  'running ray.wait on '
#  '[ObjectRef(ce868e48e2fa9a940828dc4edad993652dc48edd0200000001000000), '
#  'ObjectRef(f81ec6ff838b16db2cd4ebce5bde2b44108b06140200000001000000)]\n'
#  'running ray.wait on '
#  '[ObjectRef(f81ec6ff838b16db2cd4ebce5bde2b44108b06140200000001000000), '
#  'ObjectRef(32b0eec39cfa87ac0828dc4edad993652dc48edd0200000001000000)]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:GPU available: False, used: '
#  'False\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:TPU available: False, '
#  'using: 0 TPU cores\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:IPU available: False, '
#  'using: 0 IPUs\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:  '
#  '0%|          | 0/9912422 [00:00<?, ?it/s][0]:\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]: '
#  '85%|████████▍ | 8382464/9912422 [00:00<00:00, 83782971.28it/s]\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:  '
#  '0%|          | 0/28881 [00:00<?, ?it/s]\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:  '
#  '0%|          | 0/1648877 [00:00<?, ?it/s]\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:All distributed processes '
#  'registered. Starting with 2 processes\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Missing logger folder: '
#  '/tmp/ray/session_2023-11-02_18-46-31_525953_8/runtime_resources/working_dir_files/_ray_pkg_bb1e6d3bc4630ea8/lightning_logs\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:  | Name          | '
#  'Type       | Params | In sizes    | Out sizes\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:0 | model         | '
#  'Sequential | 13.0 K | [1, 28, 28] | [1, 10]  \n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:1 | val_accuracy  | '
#  'Accuracy   | 0      | ?           | ?        \n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:2 | test_accuracy | '
#  'Accuracy   | 0      | ?           | ?        \n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:13.0 K    Trainable params\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:0         Non-trainable '
#  'params\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:13.0 K    Total params\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:0.052     Total estimated '
#  'model params size (MB)\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b '
#  '[0]:/tmp/ray/session_2023-11-02_18-46-31_525953_8/runtime_resources/pip/3510e0c008a5c3627e4d2408c8b93ed71be6c3e1/virtualenv/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:132: '
#  'UserWarning: The dataloader, val_dataloader 0, does not have many workers '
#  'which may be a bottleneck. Consider increasing the value of the '
#  '`num_workers` argument` (try 12 which is the number of cpus on this machine) '
#  'in the `DataLoader` init to improve performance.\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:  rank_zero_warn(\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b '
#  '[0]:/tmp/ray/session_2023-11-02_18-46-31_525953_8/runtime_resources/pip/3510e0c008a5c3627e4d2408c8b93ed71be6c3e1/virtualenv/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:132: '
#  'UserWarning: The dataloader, train_dataloader, does not have many workers '
#  'which may be a bottleneck. Consider increasing the value of the '
#  '`num_workers` argument` (try 12 which is the number of cpus on this machine) '
#  'in the `DataLoader` init to improve performance.\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:  rank_zero_warn(\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:[W reducer.cpp:1289] '
#  'Warning: find_unused_parameters=True was specified in DDP constructor, but '
#  'did not find any unused parameters in the forward pass. This flag results in '
#  'an extra traversal of the autograd graph every iteration,  which can '
#  'adversely affect performance. If your model indeed never has any unused '
#  'parameters in the forward pass, consider turning this flag off. Note that '
#  'this warning may be a false positive if your model has flow control causing '
#  'later iterations to have unused parameters. (function operator())\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:prior to '
#  'running the trainer\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:MASTER_ADDR: is  10.134.0.130\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:MASTER_PORT: is  29500\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:instantiating model with hidden size: 16\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:GROUP:  2\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:LOCAL:  1\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:max '
#  'epochs: 1\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:starting '
#  'training\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:Downloading MNIST dataset...\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz '
#  'to ./MNIST/raw/train-images-idx3-ubyte.gz\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:Extracting '
#  './MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz '
#  'to ./MNIST/raw/train-labels-idx1-ubyte.gz\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:Extracting '
#  './MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz '
#  'to ./MNIST/raw/t10k-images-idx3-ubyte.gz\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:Extracting '
#  './MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz '
#  'to ./MNIST/raw/t10k-labels-idx1-ubyte.gz\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:Extracting '
#  './MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:finished '
#  'training\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:exporting '
#  'model to model.onnx\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:model '
#  'export complete\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b '
#  '[0]:initializing S3 client\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:uploading '
#  'model to model-2311021848.onnx\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:model '
#  'uploaded and available as "model-2311021848.onnx"\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:uploading '
#  'model to model-latest.onnx\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:model '
#  'uploaded and available as "model-latest.onnx"\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Validation sanity check: '
#  '0it [00:00, ?it/s]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Validation sanity check:   '
#  '0%|          | 0/2 [00:00<?, ?it/s]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Training: 0it [00:00, '
#  '?it/s]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Training:   0%|          | '
#  '0/470 [00:00<?, ?it/s]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:   0%|          | '
#  '0/470 [00:00<?, ?it/s] [0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:   4%|▍         | '
#  '20/470 [00:00<00:04, 90.73it/s]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:   4%|▍         | '
#  '20/470 [00:00<00:04, 90.64it/s, loss=2.28, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:   9%|▊         | '
#  '40/470 [00:00<00:04, 91.87it/s, loss=2.28, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:   9%|▊         | '
#  '40/470 [00:00<00:04, 91.82it/s, loss=2.18, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  13%|█▎        | '
#  '60/470 [00:00<00:04, 91.06it/s, loss=2.18, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  13%|█▎        | '
#  '60/470 [00:00<00:04, 91.03it/s, loss=2.08, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  17%|█▋        | '
#  '80/470 [00:00<00:04, 84.69it/s, loss=2.08, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  17%|█▋        | '
#  '80/470 [00:00<00:04, 84.67it/s, loss=2, v_num=0]   [0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  21%|██▏       | '
#  '100/470 [00:01<00:04, 86.33it/s, loss=2, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  21%|██▏       | '
#  '100/470 [00:01<00:04, 86.31it/s, loss=1.87, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  26%|██▌       | '
#  '120/470 [00:01<00:04, 86.09it/s, loss=1.87, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  26%|██▌       | '
#  '120/470 [00:01<00:04, 86.08it/s, loss=1.74, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  30%|██▉       | '
#  '140/470 [00:01<00:03, 87.28it/s, loss=1.74, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  30%|██▉       | '
#  '140/470 [00:01<00:03, 87.27it/s, loss=1.67, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  34%|███▍      | '
#  '160/470 [00:01<00:03, 84.28it/s, loss=1.67, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  34%|███▍      | '
#  '160/470 [00:01<00:03, 84.27it/s, loss=1.57, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  38%|███▊      | '
#  '180/470 [00:02<00:03, 84.58it/s, loss=1.57, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  38%|███▊      | '
#  '180/470 [00:02<00:03, 84.57it/s, loss=1.5, v_num=0] [0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  43%|████▎     | '
#  '200/470 [00:02<00:03, 84.76it/s, loss=1.5, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  43%|████▎     | '
#  '200/470 [00:02<00:03, 84.75it/s, loss=1.4, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  47%|████▋     | '
#  '220/470 [00:02<00:02, 85.10it/s, loss=1.4, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  47%|████▋     | '
#  '220/470 [00:02<00:02, 85.09it/s, loss=1.37, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  51%|█████     | '
#  '240/470 [00:02<00:02, 83.59it/s, loss=1.37, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  51%|█████     | '
#  '240/470 [00:02<00:02, 83.58it/s, loss=1.25, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  55%|█████▌    | '
#  '260/470 [00:03<00:02, 84.14it/s, loss=1.25, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  55%|█████▌    | '
#  '260/470 [00:03<00:02, 84.14it/s, loss=1.23, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  60%|█████▉    | '
#  '280/470 [00:03<00:02, 84.52it/s, loss=1.23, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  60%|█████▉    | '
#  '280/470 [00:03<00:02, 84.51it/s, loss=1.16, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  64%|██████▍   | '
#  '300/470 [00:03<00:02, 84.73it/s, loss=1.16, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  64%|██████▍   | '
#  '300/470 [00:03<00:02, 84.72it/s, loss=1.16, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  68%|██████▊   | '
#  '320/470 [00:03<00:01, 83.70it/s, loss=1.16, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  68%|██████▊   | '
#  '320/470 [00:03<00:01, 83.70it/s, loss=1.06, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  72%|███████▏  | '
#  '340/470 [00:04<00:01, 83.44it/s, loss=1.06, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  72%|███████▏  | '
#  '340/470 [00:04<00:01, 83.43it/s, loss=1.11, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  77%|███████▋  | '
#  '360/470 [00:04<00:01, 83.93it/s, loss=1.11, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  77%|███████▋  | '
#  '360/470 [00:04<00:01, 83.92it/s, loss=1.08, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  81%|████████  | '
#  '380/470 [00:04<00:01, 84.38it/s, loss=1.08, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  81%|████████  | '
#  '380/470 [00:04<00:01, 84.37it/s, loss=1.01, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  85%|████████▌ | '
#  '400/470 [00:04<00:00, 83.58it/s, loss=1.01, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  85%|████████▌ | '
#  '400/470 [00:04<00:00, 83.57it/s, loss=0.997, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  89%|████████▉ | '
#  '420/470 [00:05<00:00, 83.64it/s, loss=0.997, v_num=0]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0:  89%|████████▉ | '
#  '420/470 [00:05<00:00, 83.64it/s, loss=0.951, v_num=0][0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Validating: 0it [00:00, '
#  '?it/s]\x1b[A\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Validating:   0%|          '
#  '| 0/40 [00:00<?, ?it/s]\x1b[A[0]:\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Validating:  50%|█████     '
#  '| 20/40 [00:00<00:00, 110.26it/s]\x1b[A\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b '
#  '[0]:                                                            \x1b[A\n'
#  'running ray.wait on '
#  '[ObjectRef(f81ec6ff838b16db2cd4ebce5bde2b44108b06140200000001000000)]\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:prior to running the '
#  'trainer\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:MASTER_PORT: is  '
#  '29500\x1b [repeated 2x across cluster] (Ray deduplicates logs by '
#  'default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see '
#  'https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication '
#  'for more options.)\x1b\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:instantiating model with '
#  'hidden size: 16\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Epoch 0: 100%|██████████| '
#  '470/470 [00:05<00:00, 85.88it/s, loss=0.938, v_num=0, val_loss=0.748, '
#  'val_acc=0.812]\x1b [repeated 24x across cluster]\x1b\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:max epochs: 1\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:finished training\x1b '
#  '[repeated 2x across cluster]\x1b\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Downloading MNIST '
#  'dataset...\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Downloading '
#  'http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to '
#  './MNIST/raw/t10k-labels-idx1-ubyte.gz\x1b [repeated 4x across '
#  'cluster]\x1b\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:Extracting '
#  './MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw\x1b [repeated 4x '
#  'across cluster]\x1b\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:exporting model to '
#  'model.onnx\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:model export complete\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:initializing S3 client\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:uploading model to '
#  'model-2311021848.onnx\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:model uploaded and '
#  'available as "model-2311021848.onnx"\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:uploading model to '
#  'model-latest.onnx\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:model uploaded and '
#  'available as "model-latest.onnx"\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b '
#  '[0]:-----------------------------------------------------------------------\x1b '
#  '[repeated 22x across cluster]\x1b\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]: 69%|██████▉   | '
#  '6831104/9912422 [00:00<00:00, 29634005.20it/s]\x1b [repeated 2x across '
#  'cluster]\x1b\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:  0%|          | 0/4542 '
#  '[00:00<?, ?it/s]\x1b [repeated 4x across cluster]\x1b\n'
#  '\x1b\x1b(CommandActor pid=410)\x1b [0]:initializing distributed: '
#  'GLOBAL_RANK: 0, MEMBER: 1/2\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:Missing '
#  'logger folder: '
#  '/tmp/ray/session_2023-11-02_18-46-31_525953_8/runtime_resources/working_dir_files/_ray_pkg_bb1e6d3bc4630ea8/lightning_logs\n'
#  '\x1b\x1b(CommandActor pid=256, ip=10.134.0.131)\x1b [0]:[W '
#  'reducer.cpp:1289] Warning: find_unused_parameters=True was specified in DDP '
#  'constructor, but did not find any unused parameters in the forward pass. '
#  'This flag results in an extra traversal of the autograd graph every '
#  'iteration,  which can adversely affect performance. If your model indeed '
#  'never has any unused parameters in the forward pass, consider turning this '
#  'flag off. Note that this warning may be a false positive if your model has '
#  'flow control causing later iterations to have unused parameters. (function '
#  'operator())\n')

# %%
clean_up(cluster, auth)
# Out:
# shutting down cluster and logging out
# cleanup complete
