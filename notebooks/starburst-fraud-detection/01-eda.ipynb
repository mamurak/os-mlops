# %% [markdown]
# # Exploratory analysis
#
# We aren't focusing on defining metrics or data cleaning in this workshop, so our first step will be exploratory analysis on a prepared dataset.  This will involve looking at the data and then examining each variable to see if we can identify any interesting patterns.

# %% [markdown]
# We will use a range of Python libraries to help us explore, visualise and interact with the data. We could install these into the running environment, one by one. For example:
#
# `!pip install numpy`
#
# would install `numpy`. However, it is good practice to keep track of all your requirements and specific versions in one location. The explicit versions of the libraries we will use are listed in the `requirements.txt` file, which you can open from the file viewer on the left hand side of the screen. We install all these requirements into our environment below:

# %%
# !pip install -r requirements.txt
# Out:
# Collecting numpy==1.21.0
#   Downloading numpy-1.21.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 157.0 MB/s eta 0:00:00a 0:00:01
# Collecting scipy==1.7.1
#   Downloading scipy-1.7.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.4/28.4 MB 203.4 MB/s eta 0:00:00a 0:00:01
# Collecting pandas==1.3.2
#   Downloading pandas-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 200.0 MB/s eta 0:00:00a 0:00:01
# Collecting scikit-learn==0.24.1
#   Downloading scikit_learn-0.24.1-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 255.8 MB/s eta 0:00:00a 0:00:01
# Collecting altair==4.1.0
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.8/727.8 kB 344.4 MB/s eta 0:00:00
# Collecting vega==3.2.0
#   Downloading vega-3.2.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.6 MB/s eta 0:00:00eta 0:00:01
# Collecting pyarrow==0.17.0
#   Downloading pyarrow-0.17.0-cp38-cp38-manylinux2014_x86_64.whl (63.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 MB 4.9 MB/s eta 0:00:00a 0:00:01
# Collecting cloudpickle==1.5.0
#   Downloading cloudpickle-1.5.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pytz>=2017.3 in /opt/app-root/lib/python3.8/site-packages (from pandas==1.3.2->-r requirements.txt (line 3)) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/app-root/lib/python3.8/site-packages (from pandas==1.3.2->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==0.24.1->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==0.24.1->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: jsonschema in /opt/app-root/lib/python3.8/site-packages (from altair==4.1.0->-r requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: toolz in /opt/app-root/lib/python3.8/site-packages (from altair==4.1.0->-r requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: entrypoints in /opt/app-root/lib/python3.8/site-packages (from altair==4.1.0->-r requirements.txt (line 5)) (0.4)
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.8/site-packages (from altair==4.1.0->-r requirements.txt (line 5)) (3.1.2)
# Collecting jupyter<2.0.0,>=1.0.0
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting qtconsole
#   Downloading qtconsole-5.4.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 290.4 MB/s eta 0:00:00
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: notebook in /opt/app-root/lib/python3.8/site-packages (from jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (6.4.12)
# Requirement already satisfied: ipywidgets in /opt/app-root/lib/python3.8/site-packages (from jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (8.0.4)
# Requirement already satisfied: ipykernel in /opt/app-root/lib/python3.8/site-packages (from jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (6.17.1)
# Requirement already satisfied: nbconvert in /opt/app-root/lib/python3.8/site-packages (from jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (7.2.5)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas==1.3.2->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.8/site-packages (from jinja2->altair==4.1.0->-r requirements.txt (line 5)) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/app-root/lib/python3.8/site-packages (from jsonschema->altair==4.1.0->-r requirements.txt (line 5)) (22.1.0)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from jsonschema->altair==4.1.0->-r requirements.txt (line 5)) (65.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/app-root/lib/python3.8/site-packages (from jsonschema->altair==4.1.0->-r requirements.txt (line 5)) (0.19.2)
# Requirement already satisfied: debugpy>=1.0 in /opt/app-root/lib/python3.8/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: nest-asyncio in /opt/app-root/lib/python3.8/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in /opt/app-root/lib/python3.8/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (24.0.1)
# Requirement already satisfied: psutil in /opt/app-root/lib/python3.8/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (5.9.4)
# Requirement already satisfied: tornado>=6.1 in /opt/app-root/lib/python3.8/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (6.2)
# Requirement already satisfied: ipython>=7.23.1 in /opt/app-root/lib/python3.8/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (7.34.0)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.8/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (23.0)
# Requirement already satisfied: traitlets>=5.1.0 in /opt/app-root/lib/python3.8/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/app-root/lib/python3.8/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/app-root/lib/python3.8/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (7.4.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /opt/app-root/lib/python3.8/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: widgetsnbextension~=4.0 in /opt/app-root/lib/python3.8/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (4.0.5)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/app-root/lib/python3.8/site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (4.12.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/app-root/lib/python3.8/site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (3.0.32)
# Requirement already satisfied: pygments in /opt/app-root/lib/python3.8/site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (2.13.0)
# Requirement already satisfied: beautifulsoup4 in /opt/app-root/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (4.6.3)
# Requirement already satisfied: jupyterlab-pygments in /opt/app-root/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: defusedxml in /opt/app-root/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: bleach in /opt/app-root/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (5.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/app-root/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: nbformat>=5.1 in /opt/app-root/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (5.7.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /opt/app-root/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (5.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/app-root/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/app-root/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/app-root/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: ipython-genutils in /opt/app-root/lib/python3.8/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: argon2-cffi in /opt/app-root/lib/python3.8/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (21.3.0)
# Requirement already satisfied: prometheus-client in /opt/app-root/lib/python3.8/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.15.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/app-root/lib/python3.8/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/app-root/lib/python3.8/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.17.0)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 243.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.8/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: backcall in /opt/app-root/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/app-root/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /opt/app-root/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /opt/app-root/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: decorator in /opt/app-root/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: fastjsonschema in /opt/app-root/lib/python3.8/site-packages (from nbformat>=5.1->nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (2.16.2)
# Requirement already satisfied: wcwidth in /opt/app-root/lib/python3.8/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.2.5)
# Requirement already satisfied: ptyprocess in /opt/app-root/lib/python3.8/site-packages (from terminado>=0.8.3->notebook->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/app-root/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: webencodings in /opt/app-root/lib/python3.8/site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/app-root/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: cffi>=1.0.1 in /opt/app-root/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (1.15.1)
# Requirement already satisfied: pycparser in /opt/app-root/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->vega==3.2.0->-r requirements.txt (line 6)) (2.21)
# Installing collected packages: qtpy, numpy, cloudpickle, scipy, pyarrow, pandas, scikit-learn, altair, qtconsole, jupyter-console, jupyter, vega
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.2.1
#     Uninstalling cloudpickle-2.2.1:
#       Successfully uninstalled cloudpickle-2.2.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Uninstalling scipy-1.9.3:
#       Successfully uninstalled scipy-1.9.3
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 11.0.0
#     Uninstalling pyarrow-11.0.0:
#       Successfully uninstalled pyarrow-11.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.2
#     Uninstalling pandas-1.5.2:
#       Successfully uninstalled pandas-1.5.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2
#   Attempting uninstall: altair
#     Found existing installation: altair 4.2.2
#     Uninstalling altair-4.2.2:
#       Successfully uninstalled altair-4.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kfp 1.8.13 requires cloudpickle<3,>=2.0.0, but you have cloudpickle 1.5.0 which is incompatible.
# fastparquet 2023.2.0 requires pandas>=1.5.0, but you have pandas 1.3.2 which is incompatible.
# Successfully installed altair-4.1.0 cloudpickle-1.5.0 jupyter-1.0.0 jupyter-console-6.6.3 numpy-1.21.0 pandas-1.3.2 pyarrow-0.17.0 qtconsole-5.4.2 qtpy-2.3.1 scikit-learn-0.24.1 scipy-1.7.1 vega-3.2.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# We can then import the installed libraries into our notebook environment like so:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Before we get started with exploring our data, we first need to load the data. The data is stored in an S3 bucket, and we connect to it using the `boto3` library. The `boto3` library was built into the `Standard Data Science` notebook image which we selected from the spawner page. As such, it is already installed in our environment. (However, it's also good practice to keep track of every library you use in your `requirements.txt` file - go ahead and add `boto3` to the `requirements.txt`).

# %%
import boto3

# %% [markdown]
# boto3 expects all requests to be signed, meaning you have to authenticate and provide credentials (keys, ids) to connect to data. However we are connecting to public data which is in a open s3 bucket, so we use the `UNSIGNED` signature from botocore to allow us to access the data without providing credentials.

# %%
from botocore import UNSIGNED
from botocore.client import Config

s3 = boto3.client('s3', config = Config(signature_version=UNSIGNED))
s3.download_file('fraud-detection-dataset', 'fraud-cleaned-sample.parquet', 'fraud-cleaned-sample.parquet')

# %% [markdown]
# We'll start by reading in our fraud dataset and looking at the column names:

# %%
df = pd.read_parquet("fraud-cleaned-sample.parquet")
df.columns
# Out:
# Index(['timestamp', 'label', 'user_id', 'amount', 'merchant_id', 'trans_type',
#        'foreign', 'interarrival'],
#       dtype='object')

# %% [markdown]
# When dealing with an unfamiliar dataset, we first need to understand what data we've collected.  If we're lucky, our organization will publish a data catalog or data glossary that explains what each dataset contains.  If we don't have this extra metadata, we'll need to explore the dataset manually and document our observations.  Sometimes the column names will be self-explanatory, but if they aren't, we'll have to dig deeper to make sense of them.  A good second step is examining the types of each column.

# %%
df.dtypes
# Out:
# timestamp         int64
# label            string
# user_id           int32
# amount          float32
# merchant_id       int32
# trans_type       string
# foreign            bool
# interarrival    float64
# dtype: object

# %% [markdown]
# Sometimes, `string`-valued attributes in structured data are free-form text, but some string-valued variables are [categorical variables](https://en.wikipedia.org/wiki/Categorical_variable).  We can usually identify these by looking at unique values to identify attributes with a small number of possible values.

# %%
list(df["label"].unique())
# Out:
# ['legitimate', 'fraud']

# %%
list(df["trans_type"].unique())
# Out:
# ['chip_and_pin', 'contactless', 'online', 'swipe', 'manual']

# %% [markdown]
# If we're dealing with messy data, categorical variables may have a large number of unique values, some of which are spurious and may occur only once.  In this case, we don't want to examine every unique value but we can look at the top few values to get a sense for what the range of values _should_ be.  In this next cell, we're looking at the three most common transaction types.

# %%
df[["timestamp", "trans_type"]].groupby(["trans_type"]).count().nlargest(3, "timestamp")
# Out:
#               timestamp
# trans_type
# online           882304
# contactless      615511
# chip_and_pin     493596

# %% [markdown]
# We can look at the most common transaction types for each class of transaction, as well.

# %%
df[df["label"] == "fraud"][["timestamp", "trans_type"]].groupby(
    ["trans_type"]
).count(
).nlargest(3, "timestamp")
# Out:
#              timestamp
# trans_type
# online           23335
# manual           16124
# contactless       2346

# %%
df[df["label"] == "legitimate"][["timestamp", "trans_type"]].groupby(
    ["trans_type"]
).count(
).nlargest(3, "timestamp")
# Out:
#               timestamp
# trans_type
# online           858969
# contactless      613165
# chip_and_pin     491303

# %% [markdown]
# # Transaction type distribution
#
# Let's look at the transaction type first to see what the distribution looks like for legitimate and fraud transactions.

# %%
pt = pd.pivot_table(df[["label", "trans_type", "timestamp"]], 
                    index=["label", "trans_type"], aggfunc=len)

pt.columns = ['count']
gdf = pd.DataFrame(pt.to_records())

gdf['total'] = gdf.groupby('label')['count'].transform(np.sum)
gdf['percentage'] = gdf['count'] / gdf['total']

gdf
# Out:
#         label    trans_type   count    total  percentage
# 0       fraud  chip_and_pin    2293    46396    0.049422
# 1       fraud   contactless    2346    46396    0.050565
# 2       fraud        manual   16124    46396    0.347530
# 3       fraud        online   23335    46396    0.502953
# 4       fraud         swipe    2298    46396    0.049530
# 5  legitimate  chip_and_pin  491303  2453604    0.200237
# 6  legitimate   contactless  613165  2453604    0.249904
# 7  legitimate        manual  122175  2453604    0.049794
# 8  legitimate        online  858969  2453604    0.350085
# 9  legitimate         swipe  367992  2453604    0.149980

# %%
import altair as alt

alt.Chart(gdf).mark_bar().encode(
    alt.Y('percentage:Q', axis=alt.Axis(format='.0%')), column='trans_type', x="label", color='label'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Foreign transaction distribution
#
# We can repeat this process for percentage of foreign vs domestic transactions for each label.

# %%
pt = pd.pivot_table(df[["label", "foreign", "timestamp"]], 
                    index=["label", "foreign"], aggfunc=len)

pt.columns = ['count']
gdf = pd.DataFrame(pt.to_records())

gdf['total'] = gdf.groupby('label')['count'].transform(np.sum)
gdf['pctage'] = gdf['count'] / gdf['total']

gdf

alt.Chart(gdf).mark_bar().encode(
    alt.Y('pctage:Q', axis=alt.Axis(format='.0%')), column='foreign', x="label", color='label'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Transaction amount distribution
#
# When we're dealing with continuous variables, rather than categorical ones, we'll need to do something other than simply counting values to make sense of their distributions (we aren't interested, for example, in knowing that there were exactly 24 transactions for \$17.35).  There are a few options for how to proceed here:
#
# 1.  we could _quantize_ values by rounding to the nearest dollar (or ten dollars, or to the nearest power of _k_ dollars),
# 1.  we could _discretize_ values by grouping nearby values into histogram buckets, or
# 1.  we could take the _cumulative distribution_ of values, which gives us a curve for the whole distribution.
#
# Let's take a look at the latter approach.

# %%
qs = df[['label','amount']].groupby('label').quantile(q=[0.01,0.05,0.1,0.25,0.5,0.75,0.9,0.95,0.99])
qs
# Out:
#                      amount
# label
# fraud      0.01    5.330000
#            0.05    6.720000
#            0.10    8.890000
#            0.25   14.660000
#            0.50   22.530001
#            0.75   28.000000
#            0.90   35.209999
#            0.95   40.652501
#            0.99   52.810001
# legitimate 0.01    3.310000
#            0.05    4.680000
#            0.10    6.740000
#            0.25   12.430000
#            0.50   20.010000
#            0.75   28.030001
#            0.90   46.080002
#            0.95   91.720001
#            0.99  495.498800

# %% [markdown]
# What does the above data mean?  For each label, we have a set of rows, corresponding to the first, fifth, tenth, ..., ninety-fifth, and ninety-ninth percentiles.  The value at each row indicates the transaction amount at each percentile.  As an example, this means that 25% of legitimate transaction amounts are less than or equal to $12.43.
#
# We can plot the cumulative distribution of each transaction type to compare these distributions.

# %%
qdf = pd.DataFrame(qs.to_records())

alt.Chart(qdf).mark_line(interpolate="monotone").encode(
    alt.Y("amount", axis=alt.Axis(title='transaction amounts (log scale)'), scale=alt.Scale(type='log')), 
    alt.X("level_0", axis=alt.Axis(title='cumulative distribution'), scale=alt.Scale(type='linear')), 
    color="label"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# As we can see, relatively more of the fraudulent transactions are for low dollar amounts.

# %% [markdown]
# # Interarrival times
#
# Another interesting feature to look at is the distribution of interarrival times, or the time gaps between transactions.  Our intuition is that legitimate transactions will be spread apart further (and will have some large gaps), while fraudulent transactions will cluster together.

# %%
fraudsamp = df[df["label"] == "fraud"].copy()
legitsamp = df[df["label"] == "legitimate"].sample(len(fraudsamp)).copy()

fraudsamp['irank'] = fraudsamp['interarrival'].rank(pct=True, method="dense")
legitsamp['irank'] = legitsamp['interarrival'].rank(pct=True, method="dense")
qdf = pd.concat([fraudsamp.groupby(['label', 'interarrival', 'irank']).size(), legitsamp.groupby(['label', 'interarrival', 'irank']).size()])
qdf = pd.DataFrame(pd.DataFrame(qdf).to_records())
qdf = qdf[qdf['interarrival'] > 0]

# %%
alt.Chart(qdf.sample(5000)).mark_line().encode(
    alt.Y("interarrival", axis=alt.Axis(title='interarrival time'), scale=alt.Scale(type='log')), 
    alt.X("irank", axis=alt.Axis(title='cumulative distribution'), scale=alt.Scale(type='linear')), 
    color="label"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Activity by time of day
#
# We've generated users to act during typical sleep-wake cycles at different times of day.  (To simplify things, the data generator assumes that a user with a user ID _k_ is in time zone _t_ if _k_ mod 24 == _t_.)  As we'll see, legitimate transactions are centered around waking hours, while fraudulent transactions are roughly equally likely to happen at any time of day.

# %%
df["hour"] = df["timestamp"] % 86400 // 3600
df["tz"] = df["user_id"] % 24

tzpivot = pd.pivot_table(df[["label", "hour", "tz", "timestamp"]], 
                         index=["label", "hour", "tz"], aggfunc=len)

tzdf = pd.DataFrame(tzpivot.to_records()).set_axis(["label", "tz", "hour", "count"], axis="columns")

# %%
alt.Chart(tzdf).mark_area().encode(
    x="hour",
    y=alt.Y("count", stack="normalize", axis=alt.Axis(title="percentage of total")), 
    color="tz",
    column="label",
    tooltip=['label', 'tz', 'hour', 'count']
)
# Out:
# alt.Chart(...)

# %%
with open('data.csv', 'w') as outputfile:
    df.to_csv(outputfile)

# %% [markdown]
# Now that we've explored our data and visualised the distribution of values, let's move on to the next notebook, [02-feature-engineering.ipynb](02-feature-engineering.ipynb) where we transform the data into feature vectors.
